# %%
"""
Autor: Fernando Carpio Lara

"""
#import random package to generate random numbers
import random

#Define the start of the game
def rick_morty():
    """This is a decision making game based on the popular Tv series Rick and
and Morty. Here you'll find basic coding at englobe every learn so far. 
Here you'll find basic functions such as while loops, loops, if, elif, else. """
    
    #Setting character as a variable 
    character = 'Morty'
    
    #Welcome the user and let him know the game is about to start
    print(f"""
    Welcome to the Rick and Morty adventure game!!!
    Here you will join Rick in one of his adventures. 
    
    Let's get ready to start!
******************************************************************************
    """)
    #This let the user know that the game is about to start
    input(prompt= '<Press any key to continue>')
    
    #Introduction for the first part of the game with the variable character
    print(f"""
    {character} is sitting in the sofa watching interdimensional cable
    when all the sudden Rick enters the room and says
    
    Rick: "C'mon {character} I need you to come with me, we need to go this 
    planet where they have this type of crystal, that are amazing
    you wouldn't understand, but hurry come with me!"
              """)
    #Setting an input so the user has time to read
    input(prompt= 
          '<Press any key to continue when you finish reading>')
    
    #User has to make a choice so the story will move foward
    print(f"""
    {character} has to make a decision here are the different options:
    A. Go with Rick thru the portal gun
    B. Go with Rick using the space ship
    C. Stay home and continue watching interdimensional cable
    
    What are you gonna choose?
    """)
    
    #Setting decision as a variable
    decision = input(prompt= '' )
    
    #Setting a loop to make the user picks their choice 
    #the user has 3 options to get out of the loop
    while True:
        
        #Decision making for option A
        if 'gun' in decision.casefold().strip() or "portal" in decision.casefold().strip():
            print("""
    Rick: "Alright Morty let's the the he** out here."
            """)
            rick_morty_2()
            break
            
        #this to make sure the code doesn't crack while the user is putting 
        #different types of inputes
        elif 'a.' in decision.casefold().strip():
            print("""
    Rick: "Alright Morty let's the the he** out here."
            """)
            rick_morty_2()
            break
            
        #Another notation to secure the user exprience   
        elif decision.casefold().strip()== 'a':
            print("""
    Rick: "Alright Morty let's the the he** out here."
            """)
            rick_morty_2()
            break
         
        #Decision making for option B using selected words in case the user type them
        elif 'space'in decision.casefold().strip() or'ship' in decision.casefold().strip() :
            print("""
    Rick: "Alright Morty hurry up and let's the he** out here,
    by the way I'm gonna trust you on this one take the keys"
            """)
            rick_morty_2()
            break
        
        #Antoher input option to secure the flow of the game
        elif 'b.' in decision.casefold().strip(): 
            print("""
    Rick: "Alright Morty hurry up and let's the he** out here,
    by the way I'm gonna trust you on this one take the keys"
            """)
            rick_morty_2()
            break
            
        #Another notation to secure the user exprience  
        elif decision.casefold().strip() == 'b': 
            print("""
    Rick: "Alright Morty hurry up and let's the he** out here,
    by the way I'm gonna trust you on this one take the keys"
            """)
            rick_morty_2()
            break
            
        #Decision making for option C. In this choice the game will end
        #immediatly
        elif 'home' in decision.casefold().strip() or "cable" in decision.casefold().strip():
            print("""
    Rick: "Fu*** off Morty, if you continue like that you'll just a looser
    just like your father, remember nobody likes Jerry!!!"
            """)
            fail()
            break
            
        #Another notation to secure the user exprience      
        elif decision.casefold().strip() == 'c':
            print("""
    Rick: "Fu*** off Morty, if you continue like that you'll just a looser
    just like your father, remember nobody likes Jerry!!!"
            """)
            fail()
            break
            
#this to make sure the code doesn't crack while the user is putting different types of inputes   
        elif 'c.' in decision.casefold().strip():
            print("""
    Rick: "Fu*** off Morty, if you continue like that you'll just a looser
    just like your father, remember nobody likes Jerry!!!"
            """)
            fail()
            break
            
        #It bounce back to the user in case the input is not valid. 
        else:
            print("""
    That's not a valid entry, try one more time.
            """)
            input(prompt= "< Press any key to try again>")
            rick_morty() #this will restart the game at the beginning 
            break
            
  
            
#Define function that takes you to the next stage of the game            
def rick_morty_2():
    
    print("""
******************************************************************************    
    """)
    #Introduction to phase 2 of the game, where you'll be choosing your path
    print("""
    Rick: "We are here morty, look at those crystals, there are super important
    so don't mess this up okay!"
    Now here's the GPS you are gonna be in charge of directions, don't screw
    this up.
    Where shall we go?
    """)
    
    #Print the different options that the users has to keep moving forward
    print("""
    You have three option:
    A. Left
    B. Straight
    C. Right
    """)
    
    #Setting up the variable direction to choose a path
    direction = input(prompt='' )
    
    #Start a loop and depending on their answer you'll have a diferent outcomes
    while True:
    
        #Key letters to secure the next level of the game
        if 'ai' and 'tr' in direction.casefold().strip(): 
            print("""
    Rick: "Perfect morty, we are going in the right direction!".
        """)
            rick_morty_3()
            break
            
        #Different option in case the user picks a letter to move forward
        
        elif 'b.' in direction.casefold().strip():
            print("""
    Rick: "Perfect morty, we are going in the right direction!
        """)
            rick_morty_3()
            break
        elif direction.casefold().strip() == 'b':
            print("""
    Rick: "Perfect morty, we are going in the right direction!
        """)
            rick_morty_3()
            break
        
        #Option in case the user picks the left path
        elif 'e' and 'f' in direction.casefold().strip():
            print("""
    You just fell in to a crater and Rick abandoned you
            """)
            input(prompt= "< Press any key to try again>  ")
            rick_morty_2()
            break
            
        elif "a." in direction.casefold().strip():
            print("""
    You just fell in to a crater and Rick abandoned you
            """)
            input(prompt= "< Press any key to try again>  ")
            rick_morty_2()
            break
            
        elif direction.casefold().strip() == 'a':
            print("""
    You just fell in to a crater and Rick abandoned you
            """)
            input(prompt= "< Press any key to try again>  ")
            rick_morty_2()
            break
         
        #Option in case the user picks the right path
        elif 'ig' and 'h' in direction.casefold().strip():
            print("""
    You just encounter evil Morty, he takes out his blaster and kills you, 
    but don't worry Rick is find, we will get another Morty 😊👌
            """)
            input(prompt= "< Press any key to try again>  ")
            rick_morty()
            break
        
        elif 'c.' in direction.casefold().strip() :
            print("""
    You just encounter evil Morty, he takes out his blaster and kills you, 
    but don't worry Rick is find, we will get another Morty 😊👌
            """)
            input(prompt= "< Press any key to try again>  ")
            rick_morty()
            break
        
        elif direction.casefold().strip() == 'c':
            print("""
    You just encounter evil Morty, he takes out his blaster and kills you, 
    but don't worry Rick is find, we will get another Morty 😊👌
            """)
            input(prompt= "< Press any key to try again>  ")
            rick_morty()
            break
            
            
        #Condition in case the user doesn't input a valid entry    
        else:
            print("""
    That's not a valid entry, try one more time.
            """)
            input(prompt= "< Press any key to try again>  ")
            rick_morty_2()
            break
                       
#Define function that takes you to the next stage of the game            
def rick_morty_3():
    
    print("""
******************************************************************************    
    """)
    print(f"""
    After walking a couple of minutes you and Rick arrive to the mining area 
    where all the crystals, you start mining.  
    """)
    
    print(f"""
    At that moment the galactic federation arrive, and star shooting Rick and
    Morty. You and Rick take out their guns and start shooting the bugs. 
    One bug appears in front of you, you need to shoot him directly in the
    head to kill it. 
    """)
    
    #setting up the variable shoot it will take a random number between 1 - 7
    shoot = random.randint (1,5)
    
    #Starting a loop 
    while True :
        aim = input(prompt=
    '<Guess a number between 1 - 5 so you can kill the bugs> ')
        
        #Nested conditional statement depending 
        try:
            #Converting the variable in a numberical value
            aim = int(aim)
        
            #Condition when the user guess the correct number
            if aim == shoot:
                    print(f"""
    Rick: Nice shoot Morty, you just exploded that insect head. 
                """)
                    rick_morty_4()
                    break
                    
            #Condtion in case the user doesn't guess the right number
            elif aim != shoot: 
                print(f"""
    The bug shoot you but Rick put an invisible shield on you clothes
    
    Rick: "Come on I just trained you to be a good shooter! Let's take the
    crystals and get back home."
                """)
            
        except: 
            print("That's not a number, try again!")
                   
    #Else funciton is case there is an error           
    else: 
        print("Something went wrong") 
            
#Define function that takes you to the next stage of the game            
def rick_morty_4():
    
    print("""
******************************************************************************    
    """)
    #Describing the final stage of the game.
    print(f"""
    A portal opens in the garage, Rick and Morty exit it.
    
    Morty: "Oh cheezs Rick what are you gonna do with those crystal, some
    weird gun ray or are you gonna make an infinite power source?"
    """)
    
    #Place an input so the user have time to read the message
    input(prompt= '<Press any key to continue>')
    
    #Final statement to give closure to the game
    print(f"""
    Rick:" Oh Morty I admired your creativity but of course not, there are just
    for Squanchy's party, see you later as*** 😎😎😎
    """)
    
    print("""
    Congratulations you finish the adventure, and remember never trust a Rick
    except for Rick C-137 """)
    
    play_again = input(prompt= 'You want to play again? yes / no: ')
    
    #conditional statement to play again 
    if 'y' in play_again.casefold().strip():
        rick_morty()
        
    #conditional statement to quit    
    elif 'n' in play_again.casefold().strip():
        print("""
        Thanks for playing have a good day!
        """)
    #conditional statement in case there is an error.
    else:
            print("""
    That's not a valid entry, try one more time.
            """)
            input(prompt= "< Press any key to try again>  ")
            rick_morty_4() #in case there is an error the player will be back to phase 4
        
#calling funciton fail in case the user lose the game  
def fail():
    print("""
    You've lost, you wanna try one more time?
    """)
    input(prompt='<Press any key to start again>')
    rick_morty() #this will lead you back to the start of the game
    
    
rick_morty()
# Out:
#     Welcome to the Rick and Morty adventure game!!!
#     Here you will join Rick in one of his adventures.
#
#     Let's get ready to start!
# ******************************************************************************
#
# <Press any key to continue>
#
#     Morty is sitting in the sofa watching interdimensional cable
#     when all the sudden Rick enters the room and says
#
#     Rick: "C'mon Morty I need you to come with me, we need to go this
#     planet where they have this type of crystal, that are amazing
#     you wouldn't understand, but hurry come with me!"
#
# <Press any key to continue when you finish reading>
#
#     Morty has to make a decision here are the different options:
#     A. Go with Rick thru the portal gun
#     B. Go with Rick using the space ship
#     C. Stay home and continue watching interdimensional cable
#
#     What are you gonna choose?
#
# b.
#
#     Rick: "Alright Morty hurry up and let's the he** out here,
# ...
